# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.day
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
tips[['day', 'tip']]
# Out:
#       day   tip
# 0     Sun  1.01
# 1     Sun  1.66
# 2     Sun  3.50
# 3     Sun  3.31
# 4     Sun  3.61
# ..    ...   ...
# 239   Sat  5.92
# 240   Sat  2.00
# 241   Sat  2.00
# 242   Sat  1.75
# 243  Thur  3.00
#
# [244 rows x 2 columns]

# %%
tips['day'].value_counts()
# Out:
# Sat     87
# Sun     76
# Thur    62
# Fri     19
# Name: day, dtype: int64

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
# 요일별 tip이 수행된 데이터를 시각화

sns.catplot(x='day', y='tip', data=tips);

# %%
# kind='swarm' : 데이터가 겹치지 않게 나옴

sns.catplot(x='day', y='tip', data=tips, kind='swarm');
# Out:
# C:\Users\tjsdu\anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 8.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
# boxplot 설명 : https://leebaro.tistory.com/entry/%EB%B0%95%EC%8A%A4-%ED%94%8C%EB%A1%AFbox-plot-%EC%84%A4%EB%AA%85

sns.catplot(x='day', y='tip', data=tips, kind='box');

# %%
sns.catplot(x='day', y='tip', data=tips, kind='violin');

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='violin');

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='boxen');

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar');

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar', hue='day');

# %%
# point를 적용하는 범주형 데이터 차트

sns.catplot(x='day', y='total_bill', data=tips, kind='point');

# %% [markdown]
# Seaborn 즉 시각화는 데이터로 이미 시각화는 코드로 분석하면서 이해하는 top-down방식의 학습법 권장
#
# css도 top-down 권장
#
# 추상화가 너무 잘 되어 있음
#
# https://seaborn.pydata.org/tutorial/function_overview.html

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# multiple="stack" : 위에서부터 범주 값이 차례대로 쌓임

sns.displot(data=penguins, x="flipper_length_mm", hue="species", multiple="stack");

# %%
# multiple="stack"을 안쓰면 각 범주가 겹치게 됨

sns.displot(data=penguins, x="flipper_length_mm", hue="species");

# %% [markdown]
# 히트맵 : https://seaborn.pydata.org/generated/seaborn.heatmap.html?highlight=fmt

# %%
sns.set_theme()

# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights_long
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights_long['year'].value_counts()
# Out:
# 1960    12
# 1959    12
# 1958    12
# 1957    12
# 1956    12
# 1955    12
# 1954    12
# 1953    12
# 1952    12
# 1951    12
# 1950    12
# 1949    12
# Name: year, dtype: int64

# %%
flights = flights_long.pivot("month", "year", "passengers")
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
# Draw a heatmap with the numeric values in each cell
# 중요
# 섬세한 작업은 sns가 못하고 직접적으로 적용 불가한 부분이 있고, 해결책은 matplotlib
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax);

# %%
f, ax = plt.subplots(figsize=(15, 6))

sns.heatmap(flights, annot=True, fmt="d", linewidths=.5, ax=ax);

# %%
# annot=True : 각 데이터값 표현, 생략시 수치값이 안보임

f, ax = plt.subplots(figsize=(15, 6))

sns.heatmap(flights, fmt="d", linewidths=.5, ax=ax);

# %%
# f, ax 생략시 최소 사이즈로 heatmap이 그려짐 즉 사이즈 조절등은 matplotlib 필요
# f, ax = plt.subplots(figsize=(15, 6))

sns.heatmap(flights, fmt="d", annot=True, linewidths=.5);

# %%
# linewidths=.5 : 칸사이 여백을 표현하는 속성
# , fmt="d" : 정수 표기로 출력하라는 포멧 설정

f, ax = plt.subplots(figsize=(15, 6))

sns.heatmap(flights, fmt="d", annot=True);
