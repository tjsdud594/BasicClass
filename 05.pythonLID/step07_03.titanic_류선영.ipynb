# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
titanic_sns = sns.load_dataset('titanic')
titanic_sns
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
titanic = pd.read_csv('./dataset/titanic.csv', encoding='euc-kr')
titanic.head(10)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0         0       3    male  22.0      1      0   7.2500        S   Third
# 1         1       1  female  38.0      1      0  71.2833        C   First
# 2         1       3  female  26.0      0      0   7.9250        S   Third
# 3         1       1  female  35.0      1      0  53.1000        S   First
# 4         0       3    male  35.0      0      0   8.0500        S   Third
# 5         0       3    male   NaN      0      0   8.4583        Q   Third
# 6         0       1    male  54.0      0      0  51.8625        S   First
# 7         0       3    male   2.0      3      1  21.0750        S   Third
# 8         1       3  female  27.0      0      2  11.1333        S   Third
# 9         1       2  female  14.0      1      0  30.0708        C  Second
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# ...

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.columns = ['Survived', 'Pclass', 'Sex', 'Age', 'Sibsp', 'Parch', 'Fare',
       'Embarked', 'Class', 'Who', 'Adult_male', 'Deck', 'Embark_town',
       'Alive', 'Alone']
titanic
# Out:
#      Survived  Pclass     Sex   Age  Sibsp  Parch     Fare Embarked   Class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        Who  Adult_male Deck  Embark_town Alive  Alone
# ...

# %%
titanic[titanic['Age'].isnull()]
# Out:
#      Survived  Pclass     Sex  Age  Sibsp  Parch     Fare Embarked   Class  \
# 5           0       3    male  NaN      0      0   8.4583        Q   Third
# 17          1       2    male  NaN      0      0  13.0000        S  Second
# 19          1       3  female  NaN      0      0   7.2250        C   Third
# 26          0       3    male  NaN      0      0   7.2250        C   Third
# 28          1       3  female  NaN      0      0   7.8792        Q   Third
# ..        ...     ...     ...  ...    ...    ...      ...      ...     ...
# 859         0       3    male  NaN      0      0   7.2292        C   Third
# 863         0       3  female  NaN      8      2  69.5500        S   Third
# 868         0       3    male  NaN      0      0   9.5000        S   Third
# 878         0       3    male  NaN      0      0   7.8958        S   Third
# 888         0       3  female  NaN      1      2  23.4500        S   Third
#
#        Who  Adult_male Deck  Embark_town Alive  Alone
# ...

# %%
train_df = pd.read_csv('./dataset/train.csv', encoding='euc-kr')
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.columns[train_df.isnull().any()]
# Out:
# Index(['Age', 'Cabin', 'Embarked'], dtype='object')

# %%
train_df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df[train_df["Embarked"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
train_df[train_df["Age"].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 17            18         1       2              Williams, Mr. Charles Eugene
# 19            20         1       3                   Masselmani, Mrs. Fatima
# 26            27         0       3                   Emir, Mr. Farred Chehab
# 28            29         1       3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...     ...                                       ...
# 859          860         0       3                          Razi, Mr. Raihed
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
first = train_df.loc[train_data.Pclass == 1]["Survived"]
print(first)
rate_first = sum(first)/len(first)

print("% of first who survived:", rate_first)
# Out:
# 1      1
# 3      1
# 6      0
# 11     1
# 23     1
#       ..
# 871    1
# 872    0
# 879    1
# 887    1
# 889    1
# Name: Survived, Length: 216, dtype: int64
# % of first who survived: 0.6296296296296297

# %%
second = train_df.loc[train_data.Pclass == 2]["Survived"]
print(second)
rate_second = sum(second)/len(second)

print("% of second who survived:", rate_second)
# Out:
# 9      1
# 15     1
# 17     1
# 20     0
# 21     1
#       ..
# 866    1
# 874    1
# 880    1
# 883    0
# 886    0
# Name: Survived, Length: 184, dtype: int64
# % of second who survived: 0.47282608695652173

# %%
third = train_df.loc[train_data.Pclass == 3]["Survived"]
print(second)
rate_third = sum(third)/len(third)

print("% of second who survived:", rate_third)
# Out:
# 9      1
# 15     1
# 17     1
# 20     0
# 21     1
#       ..
# 866    1
# 874    1
# 880    1
# 883    0
# 886    0
# Name: Survived, Length: 184, dtype: int64
# % of second who survived: 0.24236252545824846

# %%
x = np.arange(3)
Pclass = ['first', 'second', 'third']
values = [100, 400, 900]

plt.bar(x, values)
plt.xticks(x, years)
plt.show()

# %%
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=train_df, kind="bar",
    x="Pclass", y="Age", hue="Sex",
    ci="sd", palette="dark", alpha=.6, height=6
)
g.despine(left=True)
g.set_axis_labels("", "Age")
g.legend.set_title("")

# %%
titanic['Survived'].sum()
# Out:
# 342

# %%
survived = pd.pivot_table(titanic,
                      index=titanic['Survived'],
                      columns=titanic['Class'],
                      values='Survived',
                      aggfunc='count'
                     )
survived
# Out:
# Class     First  Second  Third
# Survived
# 0            80      97    372
# 1           136      87    119

# %%
f, ax = plt.subplots(figsize=(10, 5))

sns.heatmap(survived, annot=True, fmt="d", linewidths=.5, ax=ax);

# %%
sns.catplot(x='Class', y='Survived', data=titanic, kind='bar');

# %%
sns.relplot(x='Embark_town', y='Fare', data=titanic);

# %%
sns.catplot(x='Embark_town', y='Fare', data=titanic, kind='bar');

# %%
sns.histplot(data=titanic, x="Embark_town", hue='Pclass', multiple="stack")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib\axis.py in convert_units(self, x)
#    1519         try:
# -> 1520             ret = self.converter.convert(x, self.units, self)
#    1521         except Exception as e:
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in convert(value, unit, axis)
#      60         # force an update so it also does type checking
# ---> 61         unit.update(values)
#      62         return np.vectorize(unit._mapping.__getitem__, otypes=[float])(values)
#
# ~\anaconda3\lib\site-packages\matplotlib\category.py in update(self, data)
#     210             # OrderedDict just iterates over unique values in data.
# --> 211             cbook._check_isinstance((str, bytes), value=val)
#     212             if convertible:
#
# ...

# %%
sns.relplot(x='Age', y='Fare', data=titanic, hue='Pclass', palette='flare');

# %%
# 부자다부자....!!

train[train_df['Fare'] >= 500]
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 258          259         1       1                    Ward, Miss. Anna
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C
